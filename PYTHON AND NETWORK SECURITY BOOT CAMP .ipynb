# %% [markdown]
# ##GENERATE MD5 of STRING DATA

# %%
import hashlib
data=(input("ENTER ANY WORD OR NUMBER:  "))
key=hashlib.md5(data.encode()) 
print("The converted value is: ",key)
# Out:
# ENTER ANY WORD OR NUMBER:  bijoy
# The converted value is:  <md5 HASH object @ 0x7fac82252390>

# %% [markdown]
# ##GENERATE HASHES OF STRING DATA USING 3 ALGORITHMS

# %%
import hashlib
data=(input("ENTER ANY WORD OR NUMBER:  "))
key=hashlib.sha256(data.encode())
print("The converted value is: ",key)
# Out:
# ENTER ANY WORD OR NUMBER:  bijoy1234
# The converted value is:  <sha256 HASH object @ 0x7fac7e819060>

# %%
import hashlib
data=(input("ENTER ANY WORD OR NUMBER:  "))
key=hashlib.sha1(data.encode())
print("The converted value is: ",key.hexdigest())
# Out:
# ENTER ANY WORD OR NUMBER:  bijouy678
# The converted value is:  8323556bca758e9c357f4602e61d040a705f54ae

# %%
import hashlib
data=(input("ENTER ANY WORD OR NUMBER:  "))
key=hashlib.sha3_512(data.encode())
print("The converted value is: ",key.hexdigest())
# Out:
# ENTER ANY WORD OR NUMBER:  bijoy
# The converted value is:  a4d45e554efc6bee44ce07ecfcfb6d74c413d61ffd9658305f95e962a6b7c3deefcf41461e2283e53e3f2e9a1b1851a41ea052266ad628f6b0b3ffa45b0b30b7

# %% [markdown]
# ##SALTING ***and*** ITERATION

# %%
import hashlib
import os # to generat a salt use os.urandom
salt=os.urandom(128)
key=input("enter your user name :")
convert=hashlib.pbkdf2_hmac('sha256',key.encode('utf-8'),salt,10)
print("The username is : ",convert)
# Out:
# enter your user name :bijoy789
# The username is :  b'f\xc5\xacuD!\xe6\xd27\x81\xedZ\xf5\xb1\x98\x99\xb8\x94\xdb\x84\xf77h\x07\xb9e\xa0\x8f\xcaD\x07\xcd'
